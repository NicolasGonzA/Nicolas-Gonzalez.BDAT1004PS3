# %% [markdown]
# Question 1
#
# Introduction:
# Special thanks to: https://github.com/justmarkham for sharing the dataset and
# materials.
# Occupations
# Step 1. Import the necessary libraries
# Step 2. Import the dataset from this address.
# Step 3. Assign it to a variable called users
# Step 4. Discover what is the mean age per occupation
# Step 5. Discover the Male ratio per occupation and sort it from the most to the least
# Step 6. For each occupation, calculate the minimum and maximum ages
# Step 7. For each combination of occupation and sex, calculate the mean age
# Step 8. For each occupation present the percentage of women and men

# %% [markdown]
# Step 1.

# %%
import pandas as pd

# %% [markdown]
# Step 2 and 3.

# %%
Users = pd.read_csv ('/Users/nicolasgonzalez/Downloads/u.user.csv')

# %%
Users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator     2215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %% [markdown]
# Step 4.

# %%
Users.groupby(['occupation']).mean()
# Out:
#                   user_id        age
# occupation
# administrator  430.949367  38.746835
# artist         451.892857  31.392857
# doctor         533.714286  43.571429
# educator       466.905263  42.010526
# engineer       456.328358  36.388060
# entertainment  398.000000  29.222222
# executive      422.312500  38.718750
# healthcare     501.437500  41.562500
# homemaker      443.000000  32.571429
# lawyer         359.083333  36.750000
# librarian      486.588235  40.000000
# marketing      437.807692  37.615385
# none           368.666667  26.555556
# other          542.733333  34.523810
# programmer     435.530303  33.121212
# retired        515.714286  63.071429
# salesman       494.916667  35.666667
# scientist      465.129032  35.548387
# student        484.954082  22.081633
# technician     497.629630  33.148148
# writer         495.711111  36.311111

# %% [markdown]
# Step.5

# %%
In:Users.loc[Users.occupation == 'M', 'occupation'].count()
Out
# Out:
# {6:            Emperor  Length_of_Reign         Cause_of_Death
#  0         Augustus            40.58  Possibly assassinated
#  1         Tiberius            22.50  Possibly assassinated
#  2         Caligula             4.83           Assassinated
#  3         Claudius            13.75  Possibly assassinated
#  4             Nero            13.67                Suicide
#  ..             ...              ...                    ...
#  63   Valentinian I            11.00         Natural causes
#  64          Valens            14.00       Killed in battle
#  65         Gratian            16.00           Assassinated
#  66  Valentinian II            17.00  Possibly assassinated
#  67    Theodosius I            16.00         Natural causes
#
#  [68 rows x 3 columns],
#  9:    Year  Total Arcade Revenue (billions)  \
#  0  2000                            1.196
#  1  2001                            1.176
#  2  2002                            1.269
# ...

# %% [markdown]
# Step.6

# %% [markdown]
# Step.7

# %%
Users.groupby(['gender','occupation']).mean()
# Out:
#                          user_id        age
# gender occupation
# F      administrator  443.944444  40.638889
#        artist         432.153846  30.307692
#        educator       454.730769  39.115385
#        engineer       806.500000  29.500000
#        entertainment  780.000000  31.000000
#        executive      373.000000  44.000000
#        healthcare     568.454545  39.818182
#        homemaker      367.166667  34.166667
#        lawyer         285.000000  39.500000
#        librarian      449.137931  40.000000
#        marketing      443.300000  37.200000
#        none           521.750000  36.500000
#        other          474.666667  35.472222
#        programmer     411.166667  32.166667
#        retired        860.000000  70.000000
#        salesman       637.666667  27.000000
#        scientist      611.666667  28.333333
#        student        497.533333  20.750000
#        technician     938.000000  38.000000
#        writer         536.052632  37.631579
# ...

# %% [markdown]
# Step.8
#
# Used this link for help. https://stackoverflow.com/questions/50558458/pandas-get-frequency-of-item-occurrences-in-a-column-as-percentage

# %%
Users['gender'].value_counts(normalize=True) * 100
# Out:
# M    71.049841
# F    28.950159
# Name: gender, dtype: float64

# %% [markdown]
# Tried to add ouccpation as well, however, it would not give me an output when I tried to run the code.
# I am not sure if it would give me the correct answer.

# %%
Users['gender'] = Users ['occupation'].value_counts(normalize=True) * 100

# %% [markdown]
# Question 2
#
# Euro Teams
# Step 1. Import the necessary libraries
# Step 2. Import the dataset from this address
# Step 3. Assign it to a variable called euro12
# Step 4. Select only the Goal column
# Step 5. How many team participated in the Euro2012?
# Step 6. What is the number of columns in the dataset?
# Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline
# Step 8. Sort the teams by Red Cards, then to Yellow Cards
# Step 9. Calculate the mean Yellow Cards given per Team

# %% [markdown]
# Step. 1 and
# Step. 2

# %%
import pandas as pd

euro_12 = pd.read_csv('/Users/nicolasgonzalez/Downloads/Euro_2012_stats_TEAM.csv')

# %% [markdown]
# Step. 3

# %%
euro_12
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# Step. 4

# %%
euro_12['Goals']
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %% [markdown]
# Step.5
#
# 15 teams participated in Euro 2012

# %% [markdown]
# Step.6
#
# There are 35 columns in the dataset

# %%
euro_12.shape
# Out:
# (16, 35)

# %% [markdown]
# Step.7

# %%
euro_12[['Team', 'Yellow Cards', 'Red Cards']]
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %% [markdown]
# I tried gourping the below collumns to create a new data set called "Discipline".
#
# However it output all the data and only rearranged it to show Team, Yellow Cards, and Red Cards as the first 3 collumns.
#
# I was able to (as shown above) call the selected collumns, however, was not able to create a new dataframe

# %%
Discipline = euro_12.groupby(['Team', 'Yellow Cards', 'Red Cards']).mean()

Discipline
# Out:
#                                             Goals  Shots on target  \
# Team                Yellow Cards Red Cards
# Croatia             9            0              4               13
# Czech Republic      7            0              4               13
# Denmark             4            0              4               10
# England             5            0              5               11
# France              6            0              3               22
# Germany             4            0             10               32
# Greece              9            1              5                8
# Italy               16           0              6               34
# Netherlands         5            0              2               12
# Poland              7            1              2               15
# Portugal            12           0              6               22
# Republic of Ireland 6            1              1                7
# ...

# %% [markdown]
# Step.8

# %% [markdown]
# Step.9

# %%
euro_12.groupby(['Team', 'Yellow Cards']).mean()
# Out:
#                                   Goals  Shots on target  Shots off target  \
# Team                Yellow Cards
# Croatia             9                 4               13                12
# Czech Republic      7                 4               13                18
# Denmark             4                 4               10                10
# England             5                 5               11                18
# France              6                 3               22                24
# Germany             4                10               32                32
# Greece              9                 5                8                18
# Italy               16                6               34                45
# Netherlands         5                 2               12                36
# Poland              7                 2               15                23
# Portugal            12                6               22                42
# ...

# %% [markdown]
# Step. 10
#
# #I was able to get the amount of goals that were more then 6. However, in the second attempt, I try to add the 'team' as well and receieved errors.

# %%
list(filter(lambda x: x>6,euro_12['Goals']))
# Out:
# [10, 12]

# %%
euro_12['Team']=list(filter(lambda x: x>6,euro_12['Goals']))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-a7adfbb76eb0> in <module>
# ----> 1 euro_12['Team']=list(filter(lambda x: x>6,euro_12['Goals']))
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3038         else:
#    3039             # set column
# -> 3040             self._set_item(key, value)
#    3041
#    3042     def _setitem_slice(self, key: slice, value):
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3114         """
#    3115         self._ensure_valid_index(value)
# -> 3116         value = self._sanitize_column(key, value)
#    3117         NDFrame._set_item(self, key, value)
#    3118
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3762
# ...

# %% [markdown]
# Step.11
#
# Used the following stackoverflow link for help: https://stackoverflow.com/questions/59926723/select-rows-if-string-begins-with-certain-characters-in-pandas

# %%
euro_12[euro_12['Team'].str[0].isin(['G'])]
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                     0  ...          10                 62.6%         63
# 6                     1  ...          13                 65.1%         67
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5             49        12             4          0       15        15
# 6             48        12             9          1       12        12
#
#    Players Used
# 5            17
# 6            20
#
# [2 rows x 35 columns]

# %% [markdown]
# Step.12

# %%
euro_12.head(7)
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
# 5         Germany     10               32                32             47.8%
# 6          Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# ...

# %% [markdown]
# Step.13

# %%
euro_12.head(13)
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
#
# ...

# %% [markdown]
# Step.14

# %% [markdown]
# Question 3.
#
# Housing
# Step 1. Import the necessary libraries
# Step 2. Create 3 different Series, each of length 100, as follows:
# • The first a random number from 1 to 4
# • The second a random number from 1 to 3
# • The third a random number from 10,000 to 30,000
# Step 3. Create a DataFrame by joinning the Series by column
# Step 4. Change the name of the columns to bedrs, bathrs, price_sqr_meter
# Step 5. Create a one column DataFrame with the values of the 3 Series and assign it
# to 'bigcolumn'
# Step 6. Ops it seems it is going only until index 99. Is it true?
# Step 7. Reindex the DataFrame so it goes from 0 to 299

# %% [markdown]
# Step.1

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Step.2
#
# I believe each series needed only one random number as opposed to multiple. I was not sure how to change my coding to mae each series only output one random integer.

# %%
S1 = pd.Series(np.random.randint(1,5, size=(100)))
S2 = pd.Series(np.random.randint(1,4, size = (100)))
S3 = pd.Series(np.random.randint(10001,30001, size = (100)))

print (S1)
print (S2)
print (S3)
# Out:
# 0     4
# 1     2
# 2     2
# 3     1
# 4     1
#      ..
# 95    1
# 96    1
# 97    4
# 98    1
# 99    3
# Length: 100, dtype: int64
# 0     3
# 1     1
# 2     3
# 3     1
# 4     3
#      ..
# 95    1
# 96    3
# 97    1
# 98    1
# 99    1
# Length: 100, dtype: int64
# 0     29445
# 1     12287
# 2     15558
# 3     25480
# 4     17098
#       ...
# 95    11705
# 96    15508
# 97    20340
# 98    21568
# 99    19145
# Length: 100, dtype: int64

# %% [markdown]
# Step.3

# %%
JoinedSeries = pd.DataFrame({'S1':S1, 'S2':S2, 'S3':S3})

JoinedSeries
# Out:
#     S1  S2     S3
# 0    4   3  29445
# 1    2   1  12287
# 2    2   3  15558
# 3    1   1  25480
# 4    1   3  17098
# ..  ..  ..    ...
# 95   1   1  11705
# 96   1   3  15508
# 97   4   1  20340
# 98   1   1  21568
# 99   3   1  19145
#
# [100 rows x 3 columns]

# %% [markdown]
# Step.4

# %%
JoinedSeries = pd.DataFrame({'S1':S1, 'S2':S2, 'S3':S3})

JoinedSeries.rename(columns = {'S1':'bedrs', 'S2':'bathrs', 'S3':'price_sqr_meter'},inplace=True)

JoinedSeries
# Out:
#     bedrs  bathrs  price_sqr_meter
# 0       4       3            29445
# 1       2       1            12287
# 2       2       3            15558
# 3       1       1            25480
# 4       1       3            17098
# ..    ...     ...              ...
# 95      1       1            11705
# 96      1       3            15508
# 97      4       1            20340
# 98      1       1            21568
# 99      3       1            19145
#
# [100 rows x 3 columns]

# %% [markdown]
# Step.5

# %%
bigcolumn = pd.concat([S1, S1, S3])

bigcolumn
# Out:
# 0         4
# 1         2
# 2         2
# 3         1
# 4         1
#       ...
# 95    11705
# 96    15508
# 97    20340
# 98    21568
# 99    19145
# Length: 300, dtype: int64

# %% [markdown]
# Step.6
#
# Yes, the values in the 'bigcolumn' go until index 99

# %%
Step.7

# %%
bigcolumn.index = pd.RangeIndex(start=0, stop=300)

bigcolumn
# Out:
# 0          4
# 1          2
# 2          2
# 3          1
# 4          1
#        ...
# 295    11705
# 296    15508
# 297    20340
# 298    21568
# 299    19145
# Length: 300, dtype: int64

# %% [markdown]
# Question 4
#
# Wind Statistics
# The data have been modified to contain some missing values, identified by NaN.
# Using pandas should make this exercise easier, in particular for the bonus question.
# You should be able to perform all of these operations without using a for loop or
# other looping construct.
# The data in 'wind.data' has the following format:
# Yr Mo Dy RPT VAL ROS KIL SHA BIR DUB CLA MUL CLO BEL
# MAL
# 61 1 1 15.04 14.96 13.17 9.29 NaN 9.87 13.67 10.25 10.83 12.58 18.50 15.04
# 61 1 2 14.71 NaN 10.83 6.50 12.62 7.67 11.50 10.04 9.79 9.67 17.54 13.83
# 61 1 3 18.50 16.88 12.33 10.13 11.17 6.17 11.25 NaN 8.50 7.67 12.75 12.71
#
# The first three columns are year, month, and day. The remaining 12 columns are
# average windspeeds in knots at 12 locations in Ireland on that day.
# Step 1. Import the necessary libraries
# Step 2. Import the dataset from this address
# Step 3. Assign it to a variable called data and replace the first 3 columns by a proper
# datetime index.
# Step 4. Year 2061? Do we really have data from this year? Create a function to fix it
# and apply it.
# Step 5. Set the right dates as the index. Pay attention at the data type, it should be
# datetime64[ns].
# Step 6. Compute how many values are missing for each location over the entire
# record.They should be ignored in all calculations below.
# Step 7. Compute how many non-missing values there are in total.
# Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and
# all the times.
# A single number for the entire dataset.
# Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean
# windspeeds and standard deviations of the windspeeds at each location over all the
# days
# A different set of numbers for each location.
# Step 10. Create a DataFrame called day_stats and calculate the min, max and mean
# windspeed and standard deviations of the windspeeds across all the locations at each
# day.
# A different set of numbers for each day.
# Step 11. Find the average windspeed in January for each location.
# Treat January 1961 and January 1962 both as January.
# Step 12. Downsample the record to a yearly frequency for each location.
# Step 13. Downsample the record to a monthly frequency for each location.
# Step 14. Downsample the record to a weekly frequency for each location.
# Step 15. Calculate the min, max and mean windspeeds and standard deviations of the
# windspeeds across all locations for each week (assume that the first week starts on January 2 1961) for the first 52 weeks.

# %% [markdown]
# Step 1

# %%
import pandas as pd
import datetime

# %% [markdown]
# Step 2 and 3

# %%
wind = pd.read_csv ('/Users/nicolasgonzalez/Downloads/wind.data.csv',parse_dates={'date':['Yr', 'Mo', 'Dy']})

wind
# Out:
#                                                    date    RPT    VAL    ROS  \
# 0                                                61 1 1  15.04  14.96  13.17
# 1                                                61 1 2  14.71    NaN  10.83
# 2                                                61 1 3  18.50  16.88  12.33
# 3                                                61 1 4  10.58   6.63  11.75
# 4                                                61 1 5  13.33  13.25  11.42
# ...                                                 ...    ...    ...    ...
# 6570                                           78 12 28  13.21   5.46  13.46
# 6571                                           78 12 29  14.00  10.29  14.42
# 6572                                           78 12 30  18.50  14.04  21.29
# 6573                                           78 12 31  20.33  17.41  27.29
# 6574  78 12 31 20.33 17.41 27.29  9.59 12.08 10.13 1...    NaN    NaN    NaN
#
# ...

# %% [markdown]
# Step. 4

# %% [markdown]
# Step.5

# %%
wind_dateindex =wind.set_index('date')

wind_dateindex
# Out:
#                                                       RPT    VAL    ROS  \
# date
# 61 1 1                                              15.04  14.96  13.17
# 61 1 2                                              14.71    NaN  10.83
# 61 1 3                                              18.50  16.88  12.33
# 61 1 4                                              10.58   6.63  11.75
# 61 1 5                                              13.33  13.25  11.42
# ...                                                   ...    ...    ...
# 78 12 28                                            13.21   5.46  13.46
# 78 12 29                                            14.00  10.29  14.42
# 78 12 30                                            18.50  14.04  21.29
# 78 12 31                                            20.33  17.41  27.29
# 78 12 31 20.33 17.41 27.29  9.59 12.08 10.13 19...    NaN    NaN    NaN
#
#                                                       KIL    SHA    BIR  \
# date
# ...

# %% [markdown]
# Step.6
#
# Used the followig link for help: https://www.geeksforgeeks.org/count-nan-or-missing-values-in-pandas-dataframe/

# %%
print(wind.isnull().sum())
# Out:
# date    0
# RPT     7
# VAL     4
# ROS     3
# KIL     6
# SHA     3
# BIR     1
# DUB     4
# CLA     3
# MUL     4
# CLO     2
# BEL     1
# MAL     5
# dtype: int64

# %%
wind.dropna(inplace=True)
wind
# Out:
#           date    RPT    VAL    ROS   KIL    SHA    BIR    DUB    CLA    MUL  \
# 3       61 1 4  10.58   6.63  11.75  4.58   4.54   2.88   8.63   1.79   5.83
# 4       61 1 5  13.33  13.25  11.42  6.17  10.71   8.21  11.92   6.54  10.92
# 5       61 1 6  13.21   8.12   9.96  6.67   5.37   4.50  10.67   4.42   7.17
# 6       61 1 7  13.50  14.29   9.50  4.96  12.29   8.33   9.17   9.29   7.58
# 7       61 1 8  10.96   9.75   7.62  5.91   9.62   7.29  14.29   7.62   9.25
# ...        ...    ...    ...    ...   ...    ...    ...    ...    ...    ...
# 6569  78 12 27  17.58  16.96  17.62  8.08  13.21  11.67  14.46  15.59  14.04
# 6570  78 12 28  13.21   5.46  13.46  5.00   8.12   9.42  14.33  16.25  15.25
# 6571  78 12 29  14.00  10.29  14.42  8.71   9.71  10.54  19.17  12.46  14.50
# 6572  78 12 30  18.50  14.04  21.29  9.13  12.75   9.71  18.08  12.87  12.46
# 6573  78 12 31  20.33  17.41  27.29  9.59  12.08  10.13  19.25  11.63  11.58
#
#         CLO    BEL    MAL
# ...

# %% [markdown]
# Step. 7

# %%
print(wind.notnull().sum())
# Out:
# date    6546
# RPT     6546
# VAL     6546
# ROS     6546
# KIL     6546
# SHA     6546
# BIR     6546
# DUB     6546
# CLA     6546
# MUL     6546
# CLO     6546
# BEL     6546
# MAL     6546
# dtype: int64

# %% [markdown]
# Step. 8

# %%
wind.groupby(['RPT', 'ROS', 'KIL', 'SHA', 'BIR', 'DUB', 'CLA', 'MUL', 'CLO', 'BEL', 'MAL',]).mean()
# Out:
#                                                                      VAL
# RPT   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL
# 0.67  2.96  0.87  1.38  1.21  3.63  1.54  1.71  1.42  8.67  6.79    4.50
#       4.17  0.67  4.88  0.21  1.08  2.79  1.54  5.21  2.54  13.21   3.58
# 0.79  5.88  0.75  1.79  0.96  3.04  0.83  4.46  1.58  6.21  10.88   6.79
# 0.96  4.17  2.21  4.38  3.83  6.42  5.04  5.00  6.46  9.42  13.96   2.33
# 1.00  6.46  1.21  5.25  4.04  2.79  8.08  6.21  7.12  13.50 11.54   5.09
# ...                                                                  ...
# 33.84 24.41 20.08 23.75 20.58 20.21 18.71 21.92 22.75 23.09 27.58  26.92
#       28.16 18.41 24.25 22.50 25.04 20.79 19.92 20.96 24.21 33.63  26.38
# 34.37 24.04 23.54 33.63 26.04 30.37 31.08 25.62 24.41 42.38 31.08  33.37
# 35.38 18.00 15.96 26.92 15.67 15.87 26.34 15.04 17.75 34.42 35.83  29.88
# 35.80 30.37 20.79 32.42 24.25 29.58 23.29 19.08 20.75 21.37 18.16  31.63
#
# [6546 rows x 1 columns]

# %% [markdown]
# Step.9

# %%
loc_stats = pd.DataFrame(wind).describe()

loc_stats
# Out:
#                RPT          VAL          ROS          KIL          SHA  \
# count  6546.000000  6546.000000  6546.000000  6546.000000  6546.000000
# mean     12.359979    10.640267    11.656396     6.298587    10.448923
# std       5.618805     5.268695     5.007805     3.600942     4.933988
# min       0.670000     0.210000     1.500000     0.000000     0.130000
# 25%       8.120000     6.670000     7.970000     3.580000     6.750000
# 50%      11.710000    10.130000    10.920000     5.750000     9.960000
# 75%      15.920000    14.040000    14.670000     8.380000    13.540000
# max      35.800000    33.370000    33.840000    28.460000    37.540000
#
#                BIR          DUB          CLA          MUL          CLO  \
# count  6546.000000  6546.000000  6546.000000  6546.000000  6546.000000
# mean      7.085066     9.793006     8.486601     8.490257     8.696705
# std       3.967735     4.978030     4.498299     4.165947     4.500488
# ...

# %% [markdown]
# Step.10

# %%
day_stats = pd.DataFrame(wind)

day_stats.apply(pd.Series.describe, axis=1)

print (day_stats)
# Out:
#           date    RPT    VAL    ROS   KIL    SHA    BIR    DUB    CLA    MUL  \
# 3       61 1 4  10.58   6.63  11.75  4.58   4.54   2.88   8.63   1.79   5.83
# 4       61 1 5  13.33  13.25  11.42  6.17  10.71   8.21  11.92   6.54  10.92
# 5       61 1 6  13.21   8.12   9.96  6.67   5.37   4.50  10.67   4.42   7.17
# 6       61 1 7  13.50  14.29   9.50  4.96  12.29   8.33   9.17   9.29   7.58
# 7       61 1 8  10.96   9.75   7.62  5.91   9.62   7.29  14.29   7.62   9.25
# ...        ...    ...    ...    ...   ...    ...    ...    ...    ...    ...
# 6569  78 12 27  17.58  16.96  17.62  8.08  13.21  11.67  14.46  15.59  14.04
# 6570  78 12 28  13.21   5.46  13.46  5.00   8.12   9.42  14.33  16.25  15.25
# 6571  78 12 29  14.00  10.29  14.42  8.71   9.71  10.54  19.17  12.46  14.50
# 6572  78 12 30  18.50  14.04  21.29  9.13  12.75   9.71  18.08  12.87  12.46
# 6573  78 12 31  20.33  17.41  27.29  9.59  12.08  10.13  19.25  11.63  11.58
#
#         CLO    BEL    MAL
# ...

# %% [markdown]
# Step. 11

# %%
wind_indexed = wind.set_index([1])
wind_indexed.loc[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-180-fa68190d583a> in <module>
# ----> 1 wind_indexed = wind.set_index([1])
#       2 wind_indexed.loc[1]
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4549
#    4550         if missing:
# -> 4551             raise KeyError(f"None of {missing} are in the columns")
#    4552
#    4553         if inplace:
#
# KeyError: 'None of [1] are in the columns'

# %% [markdown]
# Step.12

# %% [markdown]
# Question 5
#
# Step 1. Import the necessary libraries
# Step 2. Import the dataset from this address.
# Step 3. Assign it to a variable called chipo.
# Step 4. See the first 10 entries
# Step 5. What is the number of observations in the dataset?
# Step 6. What is the number of columns in the dataset?
# Step 7. Print the name of all the columns.
# Step 8. How is the dataset indexed?
# Step 9. Which was the most-ordered item?
# Step 10. For the most-ordered item, how many items were ordered?
# Step 11. What was the most ordered item in the choice_description column? Step 12. How many items were orderd in total?
# Step 13.
# • Turn the item price into a float
# • Check the item price type
# • Create a lambda function and change the type of item price
# • Check the item price type
# Step 14. How much was the revenue for the period in the dataset? Step 15. How many orders were made in the period?
# Step 16. What is the average revenue amount per order?
# Step 17. How many different items are sold?

# %% [markdown]
# Step. 1

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Step. 2 and 3

# %%
chipo = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep='\t')

chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# Step 4.

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
Step.5

# %%
chipo.count()
# Out:
# order_id              4622
# quantity              4622
# item_name             4622
# choice_description    3376
# item_price            4622
# dtype: int64

# %% [markdown]
# Question 6.

# %%
print(len(chipo.columns))
# Out:
# 5

# %% [markdown]
# Step.7

# %%
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %% [markdown]
# Step.8
#
# int64 and object

# %%
chipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %% [markdown]
# Step.9
#
# Chips and Fresh Tomato Salsa was the most ordered item
#
# Used the following link for help:https://datatofish.com/sort-pandas-dataframe/

# %%
chipo.sort_values(by=['quantity'],inplace=True,ascending=False)

chipo
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
# 4152      1660        10                 Bottled Water                NaN
# 3887      1559         8                 Side of Chips                NaN
# 3599      1443         7                 Bottled Water                NaN
# 2441       970         5                 Bottled Water                NaN
# ...        ...       ...                           ...                ...
# 1766       712         1           Chips and Guacamole                NaN
# 3090      1231         1           Chips and Guacamole                NaN
# 2137       860         1           Chips and Guacamole                NaN
# 2928      1165         1           Chips and Guacamole                NaN
# 3614      1448         1             6 Pack Soft Drink           [Nestea]
#
#      item_price
# 3598    $44.25
# 4152    $15.00
# 3887    $13.52
# ...

# %% [markdown]
# Step.10
#
# 15 orders were place

# %% [markdown]
# Step.11
#
# The column for choice_description shows NaN. However, I believe it would be the same item that has the most quantity sold (Chips and Fresh Tomato Salsa)

# %% [markdown]
# Step.12
#
# 4,972 is the total orders.

# %%
Total_Orders = 'quantity'
Total_Orders = chipo[Total_Orders].sum()

Total_Orders
# Out:
# 4972

# %% [markdown]
# Step.13
#
# I tried creating a dataframe called Price using the specific clumn 'item_price" within the chipo dataset in order to change the column to float.

# %%
Price = pd.DataFrame(chipo['item_price'])
pd.to_numeric(Price)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-210-1b26fb220217> in <module>
#       1 Price = pd.DataFrame(chipo['item_price'])
# ----> 2 pd.to_numeric(Price)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     137         values = np.array([arg], dtype="O")
#     138     elif getattr(arg, "ndim", 1) > 1:
# --> 139         raise TypeError("arg must be a list, tuple, 1-d array, or Series")
#     140     else:
#     141         values = arg
#
# TypeError: arg must be a list, tuple, 1-d array, or Series

# %% [markdown]
# Step.14
#
# I tried three different approaches and none worked properly. 2 of them printed all the values but did not actually add them up.

# %%
Revenue = chipo['item_price'].sum()
print (Revenue)
# Out:
# $8.99 $8.99 $8.49 $8.49 $8.49 $8.49 $10.98 $11.48 $11.48 $8.99 $8.49 $11.48 $8.99 $8.99 $10.98 $10.98 $17.98 $10.98 $8.99 $11.48 $10.98 $11.48 $10.98 $10.98 $8.99 $8.49 $8.99 $10.98 $8.49 $8.49 $11.48 $8.49 $8.99 $10.98 $8.49 $8.49 $8.49 $8.49 $8.49 $8.49 $10.98 $22.96 $21.96 $8.99 $8.49 $11.48 $11.48 $8.99 $8.99 $8.49 $8.49 $8.99 $8.49 $8.99 $11.48 $8.49 $10.98 $10.98 $8.99 $10.98 $10.98 $8.99 $8.99 $8.99 $8.99 $8.99 $8.49 $8.99 $8.99 $10.98 $8.99 $8.49 $8.49 $8.49 $8.99 $8.99 $8.49 $8.99 $8.99 $8.49 $8.99 $8.99 $11.48 $8.99 $8.99 $11.48 $16.98 $16.98 $16.98 $16.98 $16.98 $8.99 $10.98 $10.98 $10.98 $10.98 $10.98 $8.99 $8.99 $8.49 $8.99 $8.19 $8.69 $8.19 $16.38 $8.19 $8.69 $8.69 $8.69 $8.69 $8.69 $8.19 $10.98 $8.49 $8.99 $8.99 $8.99 $11.48 $11.48 $8.99 $8.99 $11.48 $10.98 $10.98 $8.99 $8.99 $8.49 $8.49 $8.49 $8.49 $8.49 $8.49 $8.49 $10.98 $10.98 $10.98 $11.48 $8.99 $8.49 $8.49 $11.48 $11.48 $8.99 $8.49 $8.99 $8.49 $8.49 $8.99 $8.49 $32.94 $8.99 $8.49 $8.99 $8.99 $8.99 $8.99 $8.49 $10
# ...

# %%
Revenue = sum(chipo['item_price'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-215-b6ea40879140> in <module>
# ----> 1 Revenue = sum(chipo['item_price'])
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
Total_Revenue = 'item_price'
Total_Revenue = chipo[Total_Revenue].sum()

Total_Revenue
# Out:
# '$8.99 $8.99 $8.49 $8.49 $8.49 $8.49 $10.98 $11.48 $11.48 $8.99 $8.49 $11.48 $8.99 $8.99 $10.98 $10.98 $17.98 $10.98 $8.99 $11.48 $10.98 $11.48 $10.98 $10.98 $8.99 $8.49 $8.99 $10.98 $8.49 $8.49 $11.48 $8.49 $8.99 $10.98 $8.49 $8.49 $8.49 $8.49 $8.49 $8.49 $10.98 $22.96 $21.96 $8.99 $8.49 $11.48 $11.48 $8.99 $8.99 $8.49 $8.49 $8.99 $8.49 $8.99 $11.48 $8.49 $10.98 $10.98 $8.99 $10.98 $10.98 $8.99 $8.99 $8.99 $8.99 $8.99 $8.49 $8.99 $8.99 $10.98 $8.99 $8.49 $8.49 $8.49 $8.99 $8.99 $8.49 $8.99 $8.99 $8.49 $8.99 $8.99 $11.48 $8.99 $8.99 $11.48 $16.98 $16.98 $16.98 $16.98 $16.98 $8.99 $10.98 $10.98 $10.98 $10.98 $10.98 $8.99 $8.99 $8.49 $8.99 $8.19 $8.69 $8.19 $16.38 $8.19 $8.69 $8.69 $8.69 $8.69 $8.69 $8.19 $10.98 $8.49 $8.99 $8.99 $8.99 $11.48 $11.48 $8.99 $8.99 $11.48 $10.98 $10.98 $8.99 $8.99 $8.49 $8.49 $8.49 $8.49 $8.49 $8.49 $8.49 $10.98 $10.98 $10.98 $11.48 $8.99 $8.49 $8.49 $11.48 $11.48 $8.99 $8.49 $8.99 $8.49 $8.49 $8.99 $8.49 $32.94 $8.99 $8.49 $8.99 $8.99 $8.99 $8.99 $8.49 $1
# ...

# %% [markdown]
# Step.14
#
# Believe question 13 had to be completed to answer this question

# %% [markdown]
# Step.15
#
#
# Believe question 13 had to be completed to answer this question

# %% [markdown]
# Step.16

# %%
chipo['item_price'] = chipo.mean(axis=1)

chipo
# Out:
#          order_id  quantity            item_name  \
# 3245       1299.0       1.0        Barbacoa Bowl
# 115          51.0       1.0        Barbacoa Bowl
# 116          51.0       1.0      Chicken Burrito
# 3051       1215.0       1.0         Chicken Bowl
# 3170       1267.0       1.0      Chicken Burrito
# ...           ...       ...                  ...
# 1766        712.0       1.0  Chips and Guacamole
# 3090       1231.0       1.0  Chips and Guacamole
# 2137        860.0       1.0  Chips and Guacamole
# 2928       1165.0       1.0  Chips and Guacamole
# Revenue       NaN       NaN                  NaN
#
#                                         choice_description  item_price
# 3245     [[Tomatillo-Red Chili Salsa (Hot), Tomatillo-G...       650.0
# 115      [[Tomatillo-Red Chili Salsa (Hot), Tomatillo-G...        26.0
# 116      [[Tomatillo-Red Chili Salsa (Hot), Tomatillo-G...        26.0
# 3051     [[Tomatillo-Red Chili Salsa (Hot), Tomatillo-G...       608.0
# ...

# %% [markdown]
# Step.17
#
# 50 different items, however, some have the same name and only have a '-' between words.

# %%
chipo['item_name'].value_counts()
# Out:
# Chicken Bowl                             726
# Chicken Burrito                          553
# Chips and Guacamole                      479
# Steak Burrito                            368
# Canned Soft Drink                        301
# Chips                                    211
# Steak Bowl                               211
# Bottled Water                            162
# Chicken Soft Tacos                       115
# Chips and Fresh Tomato Salsa             110
# Chicken Salad Bowl                       110
# Canned Soda                              104
# Side of Chips                            101
# Veggie Burrito                            95
# Barbacoa Burrito                          91
# Veggie Bowl                               85
# Carnitas Bowl                             68
# Barbacoa Bowl                             66
# Carnitas Burrito                          59
# Steak Soft Tacos                          55
# 6 Pack Soft Drink                         54
# ...

# %% [markdown]
# Question 6
#
# Create a line plot showing the number of marriages and divorces per capita in the U.S. between 1867 and 2014. Label both lines and show the legend.
# Don't forget to label your axes!

# %%
import pandas as pd

df = pd.read_csv ('/Users/nicolasgonzalez/Downloads/us-marriages-divorces-1867-2014.csv')

# %%
df
# Out:
#      Year  Marriages  Divorces  Population  Marriages_per_1000  \
# 0    1867   357000.0   10000.0    36970000                 9.7
# 1    1868   345000.0   10000.0    37885000                 9.1
# 2    1869   348000.0   11000.0    38870000                 9.0
# 3    1870   352000.0   11000.0    39905000                 8.8
# 4    1871   359000.0   12000.0    41010000                 8.8
# ..    ...        ...       ...         ...                 ...
# 140  2007  2197000.0  856000.0   301696000                 7.3
# 141  2008  2157000.0  844000.0   304543000                 7.1
# 142  2009  2080000.0  840000.0   307240000                 6.8
# 143  2010  2096000.0  872000.0   309776000                 6.8
# 144  2011  2118000.0  877000.0   312034000                 6.8
#
#      Divorces_per_1000
# 0                  0.3
# 1                  0.3
# 2                  0.3
# 3                  0.3
# 4                  0.3
# ..                 ...
# 140                2.8
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

columns = df.columns.drop(['Population', 'Marriages', 'Divorces', 'Population'])

x_data = range (0, df.shape[0])
fig, ax = plt.subplots()

for column in columns:
    ax.plot(x_data, df[column])
    
    ax.set_title('Marriages and Divorces (per_capita) 1867-2014')
    plt.xlabel('Count')
    plt.ylabel('Per 1000')
    ax.legend(columns)

# %% [markdown]
# Question 7
#
# Create a vertical bar chart comparing the number of marriages and divorces per capita in the U.S. between 1900, 1950, and 2000.
# Don't forget to label your axes!

# %%
# I tried 2 different bar graphs. I know they do not show the data properly,
#but I was unsure as to what other bar chart I could use or if I used these ones wrong.

# %%
plt.figure(figsize = (20,13))
plt.bar (x = df['Divorces_per_1000'],
        height = df['Marriages_per_1000'])
plt.xticks(rotation = 90, fontsize = 15)
plt.ylabel('Divorces per Capita ', fontsize= 12)
plt.xlabel('Marriages per Capita', fontsize= 11);
plt.title ('Divorces and Marriages per Capita', fontsize= 15, color = 'midnightblue', fontweight= 'bold')
# Out:
# Text(0.5, 1.0, 'Divorces and Marriages per Capita')

# %%
import seaborn as sns

# %%
colours = ['#F8B195','#F67280','#C06C84','#6C5B7B','#355C7D'] #Found a nice colour pallete 
df.groupby("Marriages_per_1000").Year.mean().sort_values(ascending=False)[:10].plot.bar(color=colours)
# Out:
# <AxesSubplot:xlabel='Marriages_per_1000'>

# %% [markdown]
# Question 8
#
# Create a horizontal bar chart that compares the deadliest actors in Hollywood. Sort
# the actors by their kill count and label each bar with the corresponding actor's name.
# Don't forget to label your axes!

# %%
Actors= pd.read_csv ('/Users/nicolasgonzalez/Downloads/actor_kill_counts.csv')

Actors
# Out:
#                    Actor  Count
# 0  Arnold Schwarzenegger    369
# 1           Chow Yun-Fat    295
# 2         Clint Eastwood    207
# 3             Clive Owen    194
# 4         Dolph Lundgren    239
# 5                 Jet Li    201
# 6           Nicolas Cage    204
# 7     Sylvester Stallone    267
# 8    Tomisaburo Wakayama    226
# 9          Wesley Snipes    193

# %%
colours = ['#C4E57D','#2AC280','#FFAE39','#DC5B3B','#52E397','#C5CBA3','#9CD5F6','#6E50D9'] #Found a nice colour pallete 
Actors.groupby('Actor').Count.mean().sort_values(ascending=False)[:8].plot.barh(color=colours)
# Out:
# <AxesSubplot:ylabel='Actor'>

# %% [markdown]
# Question 9
#
# Create a pie chart showing the fraction of all Roman Emperors that were assassinated.
#
# Make sure that the pie chart is an even circle, labels the categories, and shows the percentage breakdown of the categories.

# %%
# I am not sure as to why the actual pie graph did not show after my coding.

# %%
import numpy as np 
import pandas as pd

# %%
Roman_Emperors = pd.read_csv ('/Users/nicolasgonzalez/Downloads/roman-emperor-reigns.csv')

Roman_Emperors
# Out:
#            Emperor  Length_of_Reign         Cause_of_Death
# 0         Augustus            40.58  Possibly assassinated
# 1         Tiberius            22.50  Possibly assassinated
# 2         Caligula             4.83           Assassinated
# 3         Claudius            13.75  Possibly assassinated
# 4             Nero            13.67                Suicide
# ..             ...              ...                    ...
# 63   Valentinian I            11.00         Natural causes
# 64          Valens            14.00       Killed in battle
# 65         Gratian            16.00           Assassinated
# 66  Valentinian II            17.00  Possibly assassinated
# 67    Theodosius I            16.00         Natural causes
#
# [68 rows x 3 columns]

# %%
import numpy as np 
import pandas as pd 
from plotly.offline import init_notebook_mode, iplot, plot
import plotly as py
init_notebook_mode(connected=True)
import plotly.graph_objs as go
import matplotlib.pyplot as plt


Roman_Emperors
pie1 = Roman_Emperors.Cause_of_Death
pie1_list = [str(each.replace(',', '.')) for each in Roman_Emperors.Cause_of_Death]  # str(2,4) => str(2.4) = > float(2.4) = 2.4
labels = Roman_Emperors.Emperor
fig = {
  "data": [
    {
      "values": pie1_list,
      "labels": labels,
      "domain": {"x": [.2, .5]},
      "name": "Emperor Name",
      "hoverinfo":"label+percent+name",
      "hole": .3,
      "type": "pie"
    },],
  "layout": {
        "title":"Fraction of all Assasinated Roman Emperors",
        "annotations": [
            { "font": { "size": 20},
              "showarrow": False,
              "text": "Assasinated",
                "x": 0.20,
                "y": 1
            
             
            },
        ]
    }
}
iplot(fig)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %% [markdown]
# Question 10
#
# Create a scatter plot showing the relationship between the total revenue earned by
# arcades and the number of Computer Science PhDs awarded in the U.S. between 2000 and 2009.

# %%
CS_PHDS = pd.read_csv ('/Users/nicolasgonzalez/Downloads/arcade-revenue-vs-cs-doctorates.csv')

# %%
CS_PHDS
# Out:
#    Year  Total Arcade Revenue (billions)  \
# 0  2000                            1.196
# 1  2001                            1.176
# 2  2002                            1.269
# 3  2003                            1.240
# 4  2004                            1.307
# 5  2005                            1.435
# 6  2006                            1.601
# 7  2007                            1.654
# 8  2008                            1.803
# 9  2009                            1.734
#
#    Computer Science Doctorates Awarded (US)
# 0                                       861
# 1                                       830
# 2                                       809
# 3                                       867
# 4                                       948
# 5                                      1129
# 6                                      1453
# 7                                      1656
# 8                                      1787
# 9                                      1611

# %%
import seaborn as sns

sns.scatterplot(x='Computer Science Doctorates Awarded (US)', y='Total Arcade Revenue (billions)', hue='Year', data=CS_PHDS)
# Out:
# <AxesSubplot:xlabel='Computer Science Doctorates Awarded (US)', ylabel='Total Arcade Revenue (billions)'>
